# %% [markdown]
# <a href="https://colab.research.google.com/github/alysonbz/lab_prog_si/blob/camila_araujo/aula_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict = {'coutry':['brasil', 'russia', 'india', 'china', 'south africa'],
        'capital': ['brasilia', 'moscow', 'new delhi', 'beijing', 'pretoria'],
        'area': [8.516, 17.10, 3.286, 9.597, 1.221],
        'population': [200.4, 143.5, 1252, 1357, 52.98]}

# %%
import pandas as pd
brics = pd.DataFrame(dict)
brics
# Out:
#          coutry    capital    area  population
# 0        brasil   brasilia   8.516      200.40
# 1        russia     moscow  17.100      143.50
# 2         india  new delhi   3.286     1252.00
# 3         china    beijing   9.597     1357.00
# 4  south africa   pretoria   1.221       52.98

# %%
brics.index = ['BR', 'RU', 'IN', 'CH', 'SA']
brics
# Out:
#           coutry    capital    area  population
# BR        brasil   brasilia   8.516      200.40
# RU        russia     moscow  17.100      143.50
# IN         india  new delhi   3.286     1252.00
# CH         china    beijing   9.597     1357.00
# SA  south africa   pretoria   1.221       52.98

# %%
import pandas as pd
brics = pd.read_csv('https://drive.usercontent.google.com/download?id=1AyKIujQCftGvsAZRMjrHBj8pSXPAzRq_&export=download&authuser=1', index_col = 0)
brics
# Out:
#                  country    capital    area  population
# country_ab
# BR                Brazil   Brasilia   8.516      200.40
# RU                Russia     Moscow  17.100      143.50
# IN                 India  New Delhi   3.286     1252.00
# CH                 China    Beijing   9.597     1357.00
# SA          South Africa   Pretoria   1.221       52.98

# %% [markdown]
# pratique 121

# %%
import pandas as pd
names = ['Unitend States', 'Australia', 'Japan', 'India', 'russia', 'Morocco', 'Egypt' ]
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

my_dict = {'country': names,'drives_right': dr, 'cars_per_cap': cpc}

cars = pd.DataFrame(my_dict)

print(cars)
# Out:
#           country  drives_right  cars_per_cap
# 0  Unitend States          True           809
# 1       Australia         False           731
# 2           Japan         False           588
# 3           India         False            18
# 4          russia          True           200
# 5         Morocco          True            70
# 6           Egypt          True            45

# %% [markdown]
# pratique 122

# %%
import pandas as pd
names = ['Unitend States', 'Australia', 'Japan', 'India', 'russia', 'Morocco', 'Egypt' ]
dr = [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
cars_dict = {'coutry': names, 'drives_right': dr, 'cars_per_cap': cpc}
cars = pd.DataFrame(cars_dict)
print(cars)

row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

cars.index = row_labels

print(cars)
# Out:
#            coutry  drives_right  cars_per_cap
# 0  Unitend States          True           809
# 1       Australia         False           731
# 2           Japan         False           588
# 3           India         False            18
# 4          russia          True           200
# 5         Morocco          True            70
# 6           Egypt          True            45
#              coutry  drives_right  cars_per_cap
# US   Unitend States          True           809
# AUS       Australia         False           731
# JPN           Japan         False           588
# IN            India         False            18
# RU           russia          True           200
# MOR         Morocco          True            70
# EG            Egypt          True            45

# %%
#primeira análise
brics["area"]
# Out:
# country_ab
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
brics["area"] > 1000
# Out:
# country_ab
# BR    False
# RU    False
# IN    False
# CH    False
# SA    False
# Name: area, dtype: bool

# %%
is_huge = brics['area'] > 8
brics[is_huge]
# Out:
#            country   capital    area  population
# country_ab
# BR          Brazil  Brasilia   8.516       200.4
# RU          Russia    Moscow  17.100       143.5
# CH           China   Beijing   9.597      1357.0

# %%
brics[brics['area'] > 8]
# Out:
#            country   capital    area  population
# country_ab
# BR          Brazil  Brasilia   8.516       200.4
# RU          Russia    Moscow  17.100       143.5
# CH           China   Beijing   9.597      1357.0

# %%
import pandas as pd
cars = pd.read_csv('https://drive.usercontent.google.com/download?id=1kp1WzC5JojaWuj_HuSWni61Upsa1N9bo&export=download&authuser=1', index_col= 0)
print(cars)

cars['drives_right']
dr = cars['drives_right'] == True
sel = cars[dr]
sel
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# AUS                  731      Australia         False
# JAP                  588          Japan         False
# IN                    18          India         False
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %%
cars[cars['drives_right'] == True]
# Out:
#             cars_per_cap        country  drives_right
# country_ab
# US                   809  United States          True
# RU                   200         Russia          True
# MOR                   70        Morocco          True
# EG                    45          Egypt          True

# %%
cars[cars['cars_per_cap'] < 100]
# Out:
#             cars_per_cap  country  drives_right
# country_ab
# IN                    18    India         False
# MOR                   70  Morocco          True
# EG                    45    Egypt          True

# %%
offset = 10
while offset != 0:
 offset = offset - 1
 print(offset)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
import random as rd
numero = 0
sorte = 100
while numero != sorte:
  numero = rd.randint(0,100)
  print(numero)
# Out:
# 54
# 78
# 44
# 17
# 46
# 55
# 69
# 56
# 84
# 21
# 85
# 88
# 19
# 57
# 93
# 9
# 42
# 69
# 97
# 3
# 95
# 4
# 62
# 74
# 7
# 82
# 14
# 89
# 33
# 100
